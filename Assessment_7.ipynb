# %% [markdown]
# <a href="https://colab.research.google.com/github/Teddy539/BigData/blob/master/Assessment_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("readr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(readr)
library(ggplot2)

# %%
rays <- read.csv("Ultraviolet rays.csv")

# %%
str(rays)
# Out:
# 'data.frame':	1000 obs. of  7 variables:
#  $ County       : chr  "高雄市" "連江縣" "臺北市" "嘉義縣" ...
#  $ PublishAgency: chr  "中央氣象局" "中央氣象局" "中央氣象局" "環境保護署" ...
#  $ PublishTime  : chr  "2020-10-29 16:00" "2020-10-29 16:00" "2020-10-29 16:00" "2020-10-29 16:00" ...
#  $ SiteName     : chr  "高雄" "馬祖" "鞍部" "阿里山" ...
#  $ UVI          : num  0.86 0.67 0.19 1 1.02 1.14 1 0.61 0.93 1.06 ...
#  $ WGS84Lat     : chr  "22,33,58" "26,10,09" "25,10,57" "23,30,30.82" ...
#  $ WGS84Lon     : chr  "120,18,57" "119,55,24" "121,31,47" "120,48,05.02" ...

# %%
head(rays)
# Out:
#   County PublishAgency PublishTime      SiteName UVI  WGS84Lat    WGS84Lon
# 1 高雄市 中央氣象局    2020-10-29 16:00 高雄     0.86 22,33,58    120,18,57
# 2 連江縣 中央氣象局    2020-10-29 16:00 馬祖     0.67 26,10,09    119,55,24
# 3 臺北市 中央氣象局    2020-10-29 16:00 鞍部     0.19 25,10,57    121,31,47
# 4 嘉義縣 環境保護署    2020-10-29 16:00 阿里山   1.00 23,30,30.82 120,48,05.02
# 5 金門縣 中央氣象局    2020-10-29 16:00 金門     1.02 24,24,26    118,17,21
# 6 臺東縣 中央氣象局    2020-10-29 16:00 蘭嶼     1.14 22,02,13    121,33,30

# %%
install.packages("showtext")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘sysfonts’, ‘showtextdb’

# %%
library(showtext)
# Out:
# Loading required package: sysfonts
#
# Loading required package: showtextdb

# %%
showtext_auto(enable = TRUE)

# %%
ggplot(rays,aes(x=PublishAgency,y=County))+geom_point()
ggplot(rays,aes(x=UVI,y=SiteName))+geom_point()
# Out:
# Warning message:
# “Removed 1 rows containing missing values (geom_point).”
# plot without title
# plot without title

# %%
ggplot(rays,aes(x=UVI))+geom_bar()
ggplot(rays,aes(x=County))+geom_bar()
# Out:
# Warning message:
# “Removed 1 rows containing non-finite values (stat_count).”
# plot without title
# plot without title

# %%
ggplot(rays,aes(x=UVI,y=County))+geom_boxplot()
ggplot(rays,aes(x=PublishAgency,y=UVI))+geom_boxplot()
# Out:
# Warning message:
# “Removed 1 rows containing non-finite values (stat_boxplot).”
# Warning message:
# “Removed 1 rows containing non-finite values (stat_boxplot).”
# plot without title
# plot without title

# %%
rays$PublishAgency <- as.factor(rays$PublishAgency)
rays$PublishTime <- as.factor(rays$PublishTime)

# %%
rays <- data.frame(gp=factor)

# %%
ggplot(rays,aes(x=SiteName,y=UVI))+facet_grid(gp~.)
# Out:
# ERROR while rich displaying an object: Error: At least one layer must contain all faceting variables: `gp`.
# * Plot is missing `gp`
# * Layer 1 is missing `gp`
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_text.default(obj)
# 9. paste(capture.output(print(obj)), collapse = "\n")
# 10. capture.output(print(obj))
# 11. evalVis(expr)
# 12. withVisible(eval(expr, pf))
# 13. eval(expr, pf)
# 14. eval(expr, pf)
# 15. print(obj)
# 16. print.ggplot(obj)
# 17. ggplot_build(x)
# 18. ggplot_build.ggplot(x)
# 19. layout$setup(data, plot$data, plot$plot_env)
# 20. f(..., self = self)
# 21. self$facet$compute_layout(data, self$facet_params)
# 22. f(...)
# 23. combine_vars(data, params$plot_env, rows, drop = params$drop)
# 24. abort(glue("At least one layer must contain all faceting variables: {var_list(names(vars))}.\n",
#   .     glue_collapse(glue("* {name} is missing {missing_txt}"),
#   .         "\n", last = "\n")))
# 25. signal_abort(cnd)
# plot without title
