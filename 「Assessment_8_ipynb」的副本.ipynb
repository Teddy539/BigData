# %% [markdown]
# <a href="https://colab.research.google.com/github/Teddy539/BigData/blob/master/%E3%80%8CAssessment_8_ipynb%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("rJava")
install.packages("jiebaR")
install.packages("tmcn")
install.packages("dplyr")
install.packages("lubridate")
install.packages("stringr")
install.packages("wordcloud")
install.packages("Rwordseg",repos = "http://R-Forge.R-project.org")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘jiebaRD’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “dependency ‘HMM’ is not available”
# Warning message in install.packages("Rwordseg", repos = "http://R-Forge.R-project.org"):
# “installation of package ‘Rwordseg’ had non-zero exit status”

# %%
library(dplyr)
library(lubridate)
library(stringr)
library(jiebaR)
library(wordcloud)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union
#
#
# Loading required package: jiebaRD
#
# Loading required package: RColorBrewer

# %%
content <- "美國總統大選投票已結束，各州於昨天陸續開票，至目前為止已開票有45州，川普取得214張選舉人票，暫時落後拜登的264張，還有5州未果開分別是內華達州（NV，6票）、賓州（PA，20票）、北卡羅萊納州（NC，15票）、喬治亞州（GA，16票）以及阿拉斯加（AK，3票），不過川普在亞歷桑那州（AZ，11票）的差距縮小，部分媒體將亞利桑那州的選舉結果從拜登勝出變成尚待結果。

根據《福斯新聞》報導，目前賓州方面由川普占有優勢，但在費城等對民主黨有利地區，仍有大量郵件票數未開出。內華達州則宣布，當地時間週四（5日）上午9時才會更新選舉結果，目前拜登略為領先。北卡羅萊納州方面，由川普保持優勢，但仍然有20萬張郵寄選票還沒有計算在內。喬治亞州同樣由川普領先，但州內民主黨據點如亞特蘭大，仍有大量票數未開。只要拜登拿下以上4州任何一州，就可宣告大勢底定，至於阿拉斯加州，也仍在進行計票。

不過亞利桑那州選情出現變化，川普持續拉近與拜登的差距，目前開出88%選票，川普落後拜登近7萬票，《福斯新聞》仍以標註拜登獲勝，不過包含《CNN》、《紐約時報》已把這州結果改為未定，扣掉亞利桑那州的11張票，川普仍以214：253落後。

這次選舉也引發多起爭議，像是川普陣營要求重要搖擺州威斯康辛州重新計票，認為其中有好幾個郡計票有違規狀況，目前由拜登拿下。另外川普陣營今天也提起訴訟，要求賓州計票作業暫停，要求過程要更透明。密西根州方面，目前由拜登勝出，但川普陣營表示已提起訴訟，要求立即停止選舉計票作業，同時要求檢視已經開完的選票。此外，川普競選團隊在喬治亞州也提起訴訟，要求暫停計票。

2020美國總統大選總計有538張選舉人票，候選人必須拿到超過270張選舉人票才能當選下一屆美國總統，所有選舉人團成員將於12月中旬在各州州治集會投票，形式上選出新任總統及副總統，國會也將在隔年1月初正式點算選舉人票，正副總統當選人則在2021年1月20日宣誓就職。"

# %%
cutter <- worker(bylines = F)

# %%
cutter[content]
# Out:
#   [1] "美國"         "總統大選"     "投票"         "已"           "結束"
#   [6] "各州"         "於"           "昨天"         "陸續"         "開票"
#  [11] "至"           "目前"         "為止"         "已"           "開票"
#  [16] "有"           "45"           "州"           "川普"         "取得"
#  [21] "214"          "張"           "選舉人"       "票"           "暫時"
#  [26] "落後"         "拜登"         "的"           "264"          "張"
#  [31] "還有"         "5"            "州"           "未果"         "開"
#  [36] "分別"         "是"           "內華達州"     "NV"           "6"
#  [41] "票"           "賓州"         "PA"           "20"           "票"
#  [46] "北卡羅萊納州" "NC"           "15"           "票"           "喬治亞州"
#  [51] "GA"           "16"           "票"           "以及"         "阿拉斯加"
#  [56] "AK"           "3"            "票"           "不過"         "川普"
#  [61] "在"           "亞歷"         "桑那州"       "AZ"           "11"
#  [66] "票"           "的"           "差距"         "縮小"         "部分"
#  [71] "媒體"         "將"           "亞利桑那州"   "的"           "選舉"
#  [76] "結果"         "從"           "拜登"         "勝出"         "變成"
#  [81] "尚待"         "結果"         "根據"         "福斯"         "新聞"
#  [86] "報導"         "目前"         "賓州"         "方面"         "由川普"
#  [91] "占有"         "優勢"         "但"           "在"           "費城"
#  [96] "等"           "對"           "民主黨"       "有利"         "地區"
# [101] "仍"           "有"           "大量"         "郵件"         "票數"
# [106] "未"           "開出"         "內華達州"     "則"           "宣布"
# [111] "當地"         "時間"         "週四"         "5"            "日"
# [116] "上午"         "9"            "時才"         "會"           "更新"
# [121] "選舉"         "結果"         "目前"         "拜登"         "略"
# [126] "為"           "領先"         "北卡羅萊納州" "方面"         "由川普"
# [131] "保持"         "優勢"         "但"           "仍然"         "有"
# [136] "20"           "萬張"         "郵寄"         "選票"         "還"
# [141] "沒有"         "計算"         "在內"         "喬治亞州"     "同樣"
# [146] "由川普"       "領先"         "但州"         "內"           "民主黨"
# [151] "據點"         "如"           "亞特蘭大"     "仍"           "有"
# [156] "大量"         "票數"         "未開"         "只要"         "拜登"
# [161] "拿下"         "以上"         "4"            "州"           "任何"
# [166] "一州"         "就"           "可"           "宣告"         "大勢"
# [171] "底定"         "至於"         "阿拉斯加州"   "也"           "仍"
# [176] "在"           "進行"         "計票"         "不過"         "亞利桑那州"
# [181] "選情"         "出現"         "變化"         "川普"         "持續"
# [186] "拉近"         "與"           "拜登"         "的"           "差距"
# [191] "目前"         "開出"         "88"           "選票"         "川普"
# [196] "落後"         "拜登"         "近"           "7"            "萬票"
# [201] "福斯"         "新聞"         "仍"           "以"           "標註"
# [206] "拜登"         "獲勝"         "不過"         "包含"         "CNN"
# [211] "紐約時報"     "已"           "把"           "這"           "州"
# [216] "結果"         "改為"         "未定"         "扣掉"         "亞利桑那州"
# [221] "的"           "11"           "張票"         "川普"         "仍"
# [226] "以"           "214"          "253"          "落後"         "這次"
# [231] "選舉"         "也"           "引發"         "多起"         "爭議"
# [236] "像是"         "川普"         "陣營"         "要求"         "重要"
# [241] "搖擺"         "州"           "威斯康辛"     "州"           "重新"
# [246] "計票"         "認為"         "其中"         "有"           "好幾個"
# [251] "郡"           "計票"         "有"           "違規"         "狀況"
# [256] "目前"         "由"           "拜登"         "拿下"         "另外"
# [261] "川普"         "陣營"         "今天"         "也"           "提起"
# [266] "訴訟"         "要求"         "賓州"         "計票"         "作業"
# [271] "暫停"         "要求"         "過程"         "要"           "更"
# [276] "透明"         "密西根州"     "方面"         "目前"         "由"
# [281] "拜登"         "勝出"         "但川普"       "陣營"         "表示"
# [286] "已"           "提起"         "訴訟"         "要求"         "立即"
# [291] "停止"         "選舉"         "計票"         "作業"         "同時"
# [296] "要求"         "檢視"         "已經"         "開完"         "的"
# [301] "選票"         "此外"         "川普"         "競選"         "團隊"
# [306] "在"           "喬治亞州"     "也"           "提起"         "訴訟"
# [311] "要求"         "暫停"         "計票"         "2020"         "美國"
# [316] "總統大選"     "總計有"       "538"          "張"           "選舉人"
# [321] "票"           "候選人"       "必須"         "拿到"         "超過"
# [326] "270"          "張"           "選舉人"       "票"           "才能"
# [331] "當選"         "下"           "一屆"         "美國"         "總統"
# [336] "所有"         "選舉人"       "團"           "成員"         "將於"
# [341] "12"           "月"           "中旬"         "在"           "各州"
# [346] "州治"         "集會"         "投票"         "形式"         "上"
# [351] "選出"         "新任"         "總統"         "及"           "副"
# [356] "總統"         "國會"         "也"           "將在"         "隔"
# [361] "年"           "1"            "月初"         "正式"         "點算"
# [366] "選舉人"       "票"           "正副"         "總統"         "當選"
# [371] "人則"         "在"           "2021"         "年"           "1"
# [376] "月"           "20"           "日"           "宣誓就職"

# %%
new_words <- c("美國總統大選","選舉人票","6票","20票","15票","16票","3票","11票","亞歷桑那州","福斯新聞","週四5日","上午9時","沒有計算在內","州內","4州","任何一州","88選票","11張票","搖擺州","7萬票","威斯康辛州","重新計票","選舉人團成員","12月中旬","副總統","隔年","1月初","正副總統","2021年1月20日","45州","214張","264張","5州","分別是","214張","好幾個郡","88選票","20萬張","郵寄選票","538張","270張","州治集會","270張")
writeLines(new_words,"new_words.txt")

stop_words <- c("已","於","至","的","但","而","也","仍","就","更","在","有","開","從")
writeLines(stop_words,"stop_words.txt")

cutter <- worker(user = "new_words.txt",stop_word = "stop_words.txt",bylines = FALSE)
seg_words <- cutter[content]
seg_words
# Out:
#   [1] "美國總統大選"  "投票"          "結束"          "各州"
#   [5] "昨天"          "陸續"          "開票"          "目前"
#   [9] "為止"          "開票"          "45州"          "川普"
#  [13] "取得"          "214張"         "選舉人票"      "暫時"
#  [17] "落後"          "拜登"          "264張"         "還有"
#  [21] "5州"           "未果"          "分別是"        "內華達州"
#  [25] "NV"            "6票"           "賓州"          "PA"
#  [29] "20票"          "北卡羅萊納州"  "NC"            "15票"
#  [33] "喬治亞州"      "GA"            "16票"          "以及"
#  [37] "阿拉斯加"      "AK"            "3票"           "不過"
#  [41] "川普"          "亞歷桑那州"    "AZ"            "11票"
#  [45] "差距"          "縮小"          "部分"          "媒體"
#  [49] "將"            "亞利桑那州"    "選舉"          "結果"
#  [53] "拜登"          "勝出"          "變成"          "尚待"
#  [57] "結果"          "根據"          "福斯新聞"      "報導"
#  [61] "目前"          "賓州"          "方面"          "由川普"
#  [65] "占有"          "優勢"          "費城"          "等"
#  [69] "對"            "民主黨"        "有利"          "地區"
#  [73] "大量"          "郵件"          "票數"          "未"
#  [77] "開出"          "內華達州"      "則"            "宣布"
#  [81] "當地"          "時間"          "週四"          "5"
#  [85] "日"            "上午9時"       "才"            "會"
#  [89] "更新"          "選舉"          "結果"          "目前"
#  [93] "拜登"          "略"            "為"            "領先"
#  [97] "北卡羅萊納州"  "方面"          "由川普"        "保持"
# [101] "優勢"          "仍然"          "20萬張"        "郵寄選票"
# [105] "還"            "沒有計算在內"  "喬治亞州"      "同樣"
# [109] "由川普"        "領先"          "州內"          "民主黨"
# [113] "據點"          "如"            "亞特蘭大"      "大量"
# [117] "票數"          "未開"          "只要"          "拜登"
# [121] "拿下"          "以上"          "4州"           "任何一州"
# [125] "可"            "宣告"          "大勢"          "底定"
# [129] "至於"          "阿拉斯加州"    "進行"          "計票"
# [133] "不過"          "亞利桑那州"    "選情"          "出現"
# [137] "變化"          "川普"          "持續"          "拉近"
# [141] "與"            "拜登"          "差距"          "目前"
# [145] "開出"          "88"            "選票"          "川普"
# [149] "落後"          "拜登"          "近"            "7萬票"
# [153] "福斯新聞"      "以"            "標註"          "拜登"
# [157] "獲勝"          "不過"          "包含"          "CNN"
# [161] "紐約時報"      "把"            "這"            "州"
# [165] "結果"          "改為"          "未定"          "扣掉"
# [169] "亞利桑那州"    "11張票"        "川普"          "以"
# [173] "214"           "253"           "落後"          "這次"
# [177] "選舉"          "引發"          "多起"          "爭議"
# [181] "像是"          "川普"          "陣營"          "要求"
# [185] "重要"          "搖擺州"        "威斯康辛州"    "重新計票"
# [189] "認為"          "其中"          "好幾個郡"      "計票"
# [193] "違規"          "狀況"          "目前"          "由"
# [197] "拜登"          "拿下"          "另外"          "川普"
# [201] "陣營"          "今天"          "提起"          "訴訟"
# [205] "要求"          "賓州"          "計票"          "作業"
# [209] "暫停"          "要求"          "過程"          "要"
# [213] "透明"          "密西根州"      "方面"          "目前"
# [217] "由"            "拜登"          "勝出"          "但川普"
# [221] "陣營"          "表示"          "提起"          "訴訟"
# [225] "要求"          "立即"          "停止"          "選舉"
# [229] "計票"          "作業"          "同時"          "要求"
# [233] "檢視"          "已經"          "開完"          "選票"
# [237] "此外"          "川普"          "競選"          "團隊"
# [241] "喬治亞州"      "提起"          "訴訟"          "要求"
# [245] "暫停"          "計票"          "2020"          "美國總統大選"
# [249] "總計有"        "538張"         "選舉人票"      "候選人"
# [253] "必須"          "拿到"          "超過"          "270張"
# [257] "選舉人票"      "才能"          "當選"          "下"
# [261] "一屆"          "美國"          "總統"          "所有"
# [265] "選舉人團成員"  "將於"          "12月中旬"      "各州"
# [269] "州治集會"      "投票"          "形式"          "上"
# [273] "選出"          "新任"          "總統"          "及"
# [277] "副總統"        "國會"          "將在"          "隔年"
# [281] "1月初"         "正式"          "點算"          "選舉人票"
# [285] "正副總統"      "當選"          "人則"          "2021年1月20日"
# [289] "宣誓就職"

# %%
txt_freq <- freq(seg_words)
txt_freq <- arrange(txt_freq, desc(freq))
head(txt_freq)
# Out:
#   char freq
# 1 拜登 9
# 2 川普 8
# 3 目前 6
# 4 要求 6
# 5 計票 5
# 6 選舉 4

# %%
install.packages("showtext")
library(showtext)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘sysfonts’, ‘showtextdb’
#
#
# Loading required package: sysfonts
#
# Loading required package: showtextdb

# %%
showtext_auto(enable = TRUE)

# %%
wordcloud(txt_freq$char, txt_freq$freq, min.freq = 2, random.order = F,
ordered.colors = F,colors = rainbow(nrow(txt_freq)))
# Out:
# plot without title
